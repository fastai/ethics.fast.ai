# %%
#hide

# %% [markdown]
# # The fast.ai ethics book
#
# > Coming in July.

# %% [markdown]
# ## Install

# %% [markdown]
# Coming soon.

# %% [markdown]
# ## How to use

# %% [markdown]
# Coming soon.
